# %%
import pandas as pd

df = pd.read_excel('datasets/FoodKeeper-Data.xls', sheet_name = 'Product')

def isNaN(string): return string != string

def keywordFinder(key):
    # print(df['Keywords'].iloc[4])
    for index  in range(len(df['Keywords'])-1):
        keywordBank = df['Keywords'].iloc[index]
        if isNaN(keywordBank) == False:
            temp = keywordBank.split(",")
            for keys in temp:
                if keys.lower() == key.lower():
                    print(keywordBank.lower(), index)
                    print("Name: ", df['Name'].iloc[index])


def foodStorage(index, dfName, foodName, information):
    '''
    1. create enum list of pantry, ref, freeze
        - give user all info...
    2. use switch or match to make the code more readable
    3. create a list of possible responses back to users,
        - Ex. "can be stored in the pantry for..."
    4. If we find the food, check whether it has any of the column info.
        - have a temp list of all possible dictonary columns, checking if isNaN
    5. return empty string '', utilizng with Brandon's code.
    
    '''
    
    storageInfo = {
        "Pantry": [
            "Pantry_Min",
            "Pantry_Max",
            "Pantry_Metric",
            "Pantry_tips",
            "DOP_Pantry_Min",
            "DOP_Pantry_Max",
            "DOP_Pantry_Metric",
            "DOP_Pantry_tips",
            "Pantry_After_Opening_Min",
            "Pantry_After_Opening_Max",
            "Pantry_After_Opening_Metric"
        ],
        "Refrigerate": [
            'Refrigerate_Min',
            'Refrigerate_Max',
            'Refrigerate_Metric',
            'Refrigerate_tips',
            'DOP_Refrigerate_Min',
            'DOP_Refrigerate_Max',
            'DOP_Refrigerate_Metric',
            'DOP_Refrigerate_tips',
            'Refrigerate_After_Opening_Min',
            'Refrigerate_After_Opening_Max',
            'Refrigerate_After_Opening_Metric',
            'Refrigerate_After_Thawing_Min',
            'Refrigerate_After_Thawing_Max',
            'Refrigerate_After_Thawing_Metric',
            'Refrigerate_Min',
        ],
        "Freeze" : [
            "Freeze_Min",
            "Freeze_Max",
            "Freeze_Metric",
            "Freeze_Tips",
            "DOP_Freeze_Min",
            "DOP_Freeze_Max",
            "DOP_Freeze_Metric",
            "DOP_Freeze_Tips"
        ]
    }

    tempCol = []
    tempString = ''
    foodName = df["Name"].iloc[index]
    info = information.lower().capitalize()

    if storageInfo.get(info):
        for column in storageInfo[info]:
            if isNaN(df[column].iloc[index]) == False:
                # print(df[column].iloc[index])
                tempCol.append(column)

    print(tempCol)
    all_info = []
    for col in tempCol:
        tempString = ''
        # if "Metric" in col:
                # if df["DOP_" + info + "_Metric"].iloc[index] not in ['Days', 'Weeks', 'Months', 'Years']: tempString = f'{info.capitalize()} is {df["DOP_" + info + "_Metric"].iloc[index]}'
                # if df[info + "_Metric"].iloc[index] not in ['Days', 'Weeks', 'Months', 'Years']: tempString = f'{info.capitalize()} is {df[info + "_Metric"].iloc[index]}'
                # if df[info + "_After_Thawing_Metric"].iloc[index] not in ['Days', 'Weeks', 'Months', 'Years']: tempString = f'{info.capitalize()} is {df[info + "_After_Thawing_Metric"].iloc[index]}'
                # if df[info + "_After_Opening_Metric"].iloc[index] not in ['Days', 'Weeks', 'Months', 'Years']: tempString = f'{info.capitalize()} is {df[info + "_After_Opening_Metric"].iloc[index]}'
        if "DOP" in col and "Min" in col:
            min = df['DOP_' + info + '_Min'].iloc[index]
            max = df['DOP_' + info + '_Max'].iloc[index]
            if min == max: tempString = f'The Date of Perish for {foodName} is {min} {df["DOP_" + info + "_Metric"].iloc[index]}'
            else: tempString = f'The Date of Perish for {foodName} is from {min} to {max} {df["DOP_" + info + "_Metric"].iloc[index]}'
        if "Min" in col and "DOP" not in col:
            min = df[info + '_Min'].iloc[index]
            max = df[info + '_Max'].iloc[index]
            if min == max: tempString = f'{foodName.capitalize()} can be stored in the {info} for {min} {df[info + "_Metric"].iloc[index]}'
            else: tempString = f'{foodName.capitalize()} can be stored in the {info} for {min} to {max} {df[info + "_Metric"].iloc[index]}'
        if "After" in col:
            if "Thawing" in col:
                min = df[info + '_After_Thawing_Min'].iloc[index]
                max = df[info + '_After_Thawing_Max'].iloc[index]
                if min == max: tempString = f'{foodName.capitalize()} can be stored in the {info} for {min} {df[info + "_After_Thawing_Metric"].iloc[index]}'
                else: tempString = f'{foodName.capitalize()} can be stored in the {info} for {min} to {max} {df[info + "_After_Thawing_Metric"].iloc[index]}'
            else:
                min = df[info + '_After_Opening_Min'].iloc[index]
                max = df[info + '_After_Opening_Max'].iloc[index]
                if min == max: tempString = f'{foodName.capitalize()} can be stored in the {info} for {min} {df[info + "_After_Opening_Metric"].iloc[index]}'
                else: tempString = f'{foodName.capitalize()} can be stored in the {info} for {min} to {max} {df[info + "_After_Opening_Metric"].iloc[index]}'
        if "tips" in col or "Tips" in col:
            if "Freeze" in col:
                if "DOP" in col: tempString += f'A tip about {foodName} the Date of Perish is {df["DOP_" + info + "_Tips"].iloc[index]}'
                else: tempString = f'A tip about {foodName} is that {df[info + "_Tips"].iloc[index]}'
            else:
                if "DOP" in col: tempString += f'A {foodName} tip about the Date of Perish is {df["DOP_" + info + "_tips"].iloc[index]}'
                else: tempString = f'A tip about {foodName} is that {df[info + "_tips"].iloc[index]}'
    
        if tempString != '': all_info.append(tempString)
    # print("this is the return:" , tempString)                    
    return all_info if len(all_info) else ['No Tip to give!']

# %%
import random

# foundKeywords = ['rice', 'butter', 'salt', 'pepper', 'fish', 'fruit']
# foundKeywords = ['Coconut']
# for k in foundKeywords:
#     print(k)
#     keywordFinder(k)
#     print('\n')

'''
Discoveries...
1. Using the foundKeywords, find semantics of tweet to utilize particular keywords.
    - natural language processing (simpler)
    - "Red Hot Chili Peppers"

Things to fix...
1. Refrigerator, Freezer (ending words)
2. some cases produce nan, figure out why
3. type casting all min and max values to int, not completly working (possible fix after above)
4. Test all index for accuracy (is it really not tip to give?)
'''

types = ['Pantry', 'Refrigerate', 'Freeze']

numIndex = 2
for i in range(numIndex):
    index = random.randint(0, 651)
    print("=== ", df["Name"].iloc[index], " ===", f' ({index})')
    for t in types:
        all_tips = foodStorage(index, df,"INSERT FOOD NAME", t)
        print(f"{t}: ")
        counter = 1
        for i in all_tips:
            print(f"\ttip {counter}:", i)
            counter += 1
    print()

# print("=== ", df["Name"].iloc[144], " ===", f' ({144})')
# for t in types:
#     all_tips = foodStorage(144, df,"INSERT FOOD NAME", t)
#     print(f"{t}: ")
#     counter = 1
#     for i in all_tips:
#         print(f"\ttip {counter}:", i)
#         counter += 1
# print(df["DOP_" + 'Refrigerate' + "_tips"].iloc[144])
# Out:
# ===  Shrimp, crayfish  ===  (137)
# []
# Pantry:
# 	tip 1: No Tip to give!
# ['DOP_Refrigerate_Min', 'DOP_Refrigerate_Max', 'DOP_Refrigerate_Metric']
# Refrigerate:
# 	tip 1: The Date of Perish for Shrimp, crayfish is from 1.0 to 3.0 Days
# ['DOP_Freeze_Min', 'DOP_Freeze_Max', 'DOP_Freeze_Metric']
# Freeze:
# 	tip 1: The Date of Perish for Shrimp, crayfish is from 6.0 to 18.0 Months
#
# ===  Pickles  ===  (331)
# ['DOP_Pantry_Min', 'DOP_Pantry_Max', 'DOP_Pantry_Metric']
# Pantry:
# 	tip 1: The Date of Perish for Pickles is 1.0 Years
# ['Refrigerate_After_Opening_Min', 'Refrigerate_After_Opening_Max', 'Refrigerate_After_Opening_Metric']
# Refrigerate:
# 	tip 1: Pickles can be stored in the Refrigerate for 1.0 to 3.0 Months
# 	tip 2: Pickles can be stored in the Refrigerate for 1.0 to 3.0 Months
# 	tip 3: Pickles can be stored in the Refrigerate for 1.0 to 3.0 Months
# []
# Freeze:
# 	tip 1: No Tip to give!
